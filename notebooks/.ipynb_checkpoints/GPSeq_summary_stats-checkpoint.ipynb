# %% [markdown]
# ## Libraries

# %%
library('ggplot2')
library('gridExtra')
library('RColorBrewer')
library(grid)
library(reshape2)
library('ggExtra')

# %%
setwd("../")

# %% [markdown]
# ## Functions

# %% [markdown]
# ### my_scatter_plot

# %%
my_scatter_plot <- function(x, y, myxlim=NULL, myylim=NULL, quantile=FALSE, myxlab="x values", myylab="y values"){
    df <- data.frame(x=x, y=y)
    if (quantile){
        myylim=quantile(df$y, c(0.001, .999), na.rm=T)
        myxlim=quantile(df$x, c(0.001, .999), na.rm=T)
    }
    p=cor.test(df$x, df$y)
    if (p$p.value == 0){
        mytext=paste(" Pearson's cor: ", round(p$estimate, digits=4), sep="") #, "\n p-value < 2.2e-16", sep="")
    } else {
        mytext=paste(" Pearson's cor: ", round(p$estimate, digits=4), sep="")} # "\n p-value: ", round(p$p.value, digits=4), sep="")}
    # ggMarginal is being weird with using scale_x_continuous, so need to filter the data with the x and y limits 
    myi = df$x<=myxlim[2] & df$x >= myxlim[1] & df$y <= myylim[2] & df$y >= myylim[1]
    p1 <- ggplot(df[myi,], aes(x,y)) + geom_point(size=.1, alpha=0.1) + 
        xlab(paste0(myxlab, "\n\n")) + ylab(paste0("\n\n", myylab)) +
        annotate("text", x=-Inf, y=Inf, label=mytext, vjust=1.1, hjust=0, size=3) + 
        theme(axis.text=element_text(size=8), text=element_text(size=9), 
              plot.title=element_text(size=1))
        #stat_density2d(aes(fill=..level..), geom="polygon")+ scale_fill_gradient(low="blue", high="orange")
    pf <- ggExtra::ggMarginal(p1, type="density", size=5, margin="both")
    return(pf)
}

my_scatter_densplot <- function(x, y, d, myxlim=NULL, myylim=NULL, quantile=FALSE, 
                                myxlab="x values", myylab="y values", mydlab="dens") {
    df <- data.frame(x=x, y=y, d_score=d)
    if (quantile){
        myylim=quantile(df$y, c(0.001, .999))
        myxlim=quantile(df$x, c(0.001, .999))
    }
    p=cor.test(df$x, df$y)
    if (p$p.value == 0){
        mytext=paste(" Pearson's cor: ", round(p$estimate, digits=4), sep="")} #, "\n p-value < 2.2e-16", sep="")
    else {
        mytext=paste(" Pearson's cor: ", round(p$estimate, digits=4), sep="")} # "\n p-value: ", round(p$p.value, digits=4), sep="")}
    myi = df$x<=myxlim[2] & df$x >= myxlim[1] & df$y <= myylim[2] & df$y >= myylim[1]

    p1 <- ggplot(df) + geom_point(aes(x=x, y=y, col=d_score), size=0.6, alpha=0.7) + 
        xlim(myxlim) + ylim(myylim) + scale_colour_gradient2() +
        labs(x=myxlab, y=myylab, colour=mydlab)
        #guides(fill=guide_legend(override.aes=list(size=3))) 
    #pf <- ggExtra::ggMarginal(p1, type="density", size=5, margin="both")
    return(p1)
}

# %%
make_into_stars<-function(x){
    s=""
    if (x <= 0.05){s="*"}
    if (x <= 0.01){s="**"}
    if (x <= 0.001){s="***"}
    if (x <= 0.0001){s="****"}
    return(s)
}

# %% [markdown]
# # Data exploration

# %%
mytimes=c("_1min", "_5min", "_10min", "_15min", "_30min", "_on")

# %%
getwd()
# Out:
# [1] "/Users/tballing/Documents/Research/GPSeq"

# %% [markdown]
# ## BICRO58

# %%
dat <- read.table("data/BICRO58_all_umiCount.txt", header=T)

myord=c()
for (i in seq(1,length(mytimes))){
    j=grep(mytimes[i], labels(dat)[[2]])
    myord=c(myord, j)
}
datc <- dat[,myord]

datc[datc==-1]=0

# %%
totumis <- apply(datc, 2, sum)
totumis
# Out:
#   TK99_1min  TK100_5min TK101_10min TK102_15min TK103_30min    TK104_on
#      342569      743976     2553632     5406052     2743576     6637521

# %%
datcnt <- apply(datc, 1, function(x) sum(x > 0))
options(repr.plot.width=8, repr.plot.height=2.5)
par(mfrow=c(1,4))
hist(datcnt, xlab="Number of samples", ylab="Number of cutsites", main="Number of cutsites with > 0 reads ")
xcnt <- apply(datc, 2, function(x) sum(x>0))
plot(xcnt, xlab="Time point", ylab="number of cutsites")
x <- apply(datc, 2, function(x) mean(x[x>0]))
plot(x, xlab="Time point", ylab="Average cuts per site")
plot(totumis, xlab="Time point", ylab="Total UMIs")
# Out:
# Plot with title “Number of cutsites with > 0 reads ”

# %% [markdown]
# ## BICRO62

# %%
dat <- read.table("GPSeq_data/BICRO62_all_umiCount.txt", header=T)

myord=c()
for (i in seq(1,length(mytimes))){
    j=grep(mytimes[i], labels(dat)[[2]])
    myord=c(myord, j)
}
datc <- dat[,myord]

datc[datc==-1]=0

# %%
totumis <- apply(datc, 2, sum)
totumis
# Out:
#  TK111_1min  TK112_5min TK113_10min TK114_15min TK115_30min    TK116_on
#     1654967     5192602    23383500    37733544    19765715    38328589

# %%
datcnt <- apply(datc, 1, function(x) sum(x > 0))
options(repr.plot.width=8, repr.plot.height=2.5)
par(mfrow=c(1,4))
hist(datcnt, xlab="Number of samples", ylab="Number of cutsites", main="Number of cutsites with > 0 reads ")
xcnt <- apply(datc, 2, function(x) sum(x>0))
plot(xcnt, xlab="Time point", ylab="number of cutsites")
x <- apply(datc, 2, function(x) mean(x[x>0]))
plot(x, xlab="Time point", ylab="Average cuts per site")
plot(totumis, xlab="Time point", ylab="Total UMIs")
# Out:
# Plot with title “Number of cutsites with > 0 reads ”

# %% [markdown]
# ## Normalize by total number of reads (cuts) per timepoint

# %%
# normalize by the total number of cuts per timepoint
datn <- datc
for (i in seq(5,ncol(dat))){
    tot=sum(dat[,i])
    datn[,i]=dat[,i]/tot
}

# %%
dattot <- apply(dat[,5:ncol(dat)], 1, function(x) sum(x[x>0]))
datm <- apply(dat[,5:10], 1, mean)
datsd <- apply(dat[,5:10], 1, sd)

# %%
max(datm)
max(datm[datm<10000])
# Out:
# [1] 43278.33
# [1] 604

# %%
# Do this because there is an outlier cutsite that has thousands of cuts
myi <- datm < 200
df2 <- data.frame(mean=datm[myi], std<-datsd[myi])
p <- ggplot(df2, aes(x=mean, y=std)) + geom_point(size=.1, alpha=0.1) + 
    xlab("Mean") + ylab("Std") + ggtitle("Mean vs sd across time points")
pf <- ggExtra::ggMarginal(p, type="density", size=5, margin="both")

# %%
options(repr.plot.width=4, repr.plot.height=4)
grid.arrange(pf)
# Out:
# plot without title

# %% [markdown]
# ## Correlation between neighboring cutsites

# %%
dat <- read.table("BICRO62_all_umiCount.txt", header=T)
dat[dat==-1]=0

mytimes=c("_1min", "_5min", "_10min", "_15min", "_30min", "_on")
myord=c()
for (i in seq(1,length(mytimes))){
    j=grep(mytimes[i], labels(dat)[[2]])
    myord=c(myord, j)
}
datc <- dat[,myord]

# %%
chrs=rle(as.character(dat$chr))$values
dmat=c()
for (chr in chrs){
    chrdat <- dat[dat$chr==chr,]
    dist <- chrdat$start[2:nrow(chrdat)] - chrdat$end[1:(nrow(chrdat)-1)]
    diffm <- dist
    for (j in seq(5,ncol(dat))){
        diff <- chrdat[2:nrow(chrdat),j] - chrdat[1:(nrow(chrdat)-1),j]
        diffm <- cbind(diffm, diff)
    }
    dmat <- rbind(dmat, diffm)
}
colnames(dmat) <- c("distance", mytimes)

# %%
dat <- read.table("GPSeq_data/raw_bed_files/BICRO62+83_TK116_on_dist.txt", header=F)
colnames(dat) <- c("cutsite1", "cutsite2", "c1", "c2", "dist")

# %%
# Do this because there is an outlier cutsite that has thousands of cuts
myi <- dat$c1 < 200 & dat$c2 < 200
df2 <- data.frame(diff= abs(dat$c2[myi]-dat$c1[myi]), dist<-dat$dist[myi])
p <- ggplot(df2, aes(y=diff, x=dist)) + geom_point(size=.1, alpha=0.1) + 
    ylab("Difference in cuts") + xlab("Distance in bp") + 
    xlim(0,5e4)
pf <- ggExtra::ggMarginal(p, type="density", size=5, margin="both")
# Out:
# Warning message:
# “Removed 496 rows containing missing values (geom_point).”

# %%
options(repr.plot.width=4, repr.plot.height=3)
grid.arrange(pf)
# Out:
# plot without title

# %% [markdown]
# ## Correlation per distance

# %%
dat <- read.table("GPSeq_data/raw_bed_files/BICRO58_TK100_5min_dist.txt", header=F)
colnames(dat) <- c("cutsite1", "cutsite2", "c1", "c2", "dist")

# %%
get_correlation_per_distance <- function(dat, distances){
    mycors <- c()
    for (d in distances){
        ddat <- dat[dat$dist < d,]
        mycor <- cor(ddat$c1, ddat$c2)
        mycors <- c(mycors, mycor)
    }
return(mycors)
}

# %%
gpseqpath="GPSeq_data/raw_bed_files"
distances <- c(10, 100, 1000, 5000, 1e4, 1e5, 5e5, 1e6)
mydc <- distances
for (tm in mytimes){
    pat <- paste0("BICRO58_.*", tm, "_dist.txt")
    f=list.files(path=gpseqpath, pattern=pat)
    dat <- read.table(paste0(gpseqpath, "/", f), header=F)
    colnames(dat) <- c("cutsite1", "cutsite2", "c1", "c2", "dist")
    mycors <- get_correlation_per_distance(dat, distances)
    mydc <- cbind(mydc, mycors)
}
colnames(mydc) <- c("distance", mytimes)

# %%
dfm <- melt(data.frame(mydc), id="distance")
p <- ggplot(dfm, aes(x=distance, y=value, colour=variable)) + geom_line() + 
    scale_x_log10() + 
    labs(x="Distance between cutsites (bp)", y="Pearson's Correlation") + 
    ggtitle("Correlation between\nneighboring points")

# %%
options(repr.plot.width=4, repr.plot.height=3)
grid.arrange(p)
# Out:
# plot without title

# %% [markdown]
# ## Correlation across time

# %%
# Read in the data
dat <- read.table("BICRO62_all_umiCount.txt", header=T)
dat[dat==-1]=0

mytimes=c("_1min", "_5min", "_10min", "_15min", "_30min", "_on")
myord=c()
for (i in seq(1,length(mytimes))){
    j=grep(mytimes[i], labels(dat)[[2]])
    myord=c(myord, j)
}
datc <- dat[,myord]

# %%
mycors=c()
myt1s=c()
myt2s=c()
for (i in seq(1,(length(mytimes)-1))){
    for (j in seq((i+1),length(mytimes))){
        mycor <- cor(datc[,i], datc[,j])
        mycors <- c(mycors, mycor)
        myt1s <- c(myt1s, mytimes[i])
        myt2s <- c(myt2s, mytimes[j])
    }
}

# %%
df <- data.frame(correlation=as.numeric(mycors), t1=factor(myt1s, levels=mytimes), t2=factor(myt2s, levels=mytimes))
p <- ggplot(df, aes(y=correlation, x=t1, colour=t2)) + geom_point() + 
    ggtitle("Correlation between time points")

# %%
options(repr.plot.width=4, repr.plot.height=3)
grid.arrange(p)
# Out:
# plot without title

# %% [markdown]
# # Histograms

# %%
make_hist_data <- function(mydat, mymax) {
    mydens <- c()
    mycnts <- c()
    for (i in seq(1,ncol(mydat))){
        myi <- mydat[,i] < mymax & mydat[,i] > (-1*mymax)
        myh <- hist(mydat[myi,i], breaks=seq(-1 * mymax, mymax, by=mymax/30), plot=F)
        if (length(mycnts)==0){
            mymids <- myh$mids
            mycnts <- myh$counts
            mydens <- myh$density 
        }
        else {
            mycnts <- cbind(mycnts, myh$counts)
            mydens <- cbind(mydens, myh$density)
        }
    }
    mydens <- cbind(mymids, mydens)
    colnames(mydens) = c("mids", labels(mydat)[[2]])
    mycnts <- cbind(mymids, mycnts)
    colnames(mycnts) = c("mids", labels(mydat)[[2]])
    return(list(mydens, mycnts))
}

# %% [markdown]
# ## Raw read counts

# %%
mytimes=c("_1min", "_5min", "_10min", "_15min", "_30min", "_on")

# %%
dat <- read.table("BICRO62_all_umiCount.txt", header=T)
myord=c()
for (i in seq(1,length(mytimes))){
    j=grep(mytimes[i], labels(dat)[[2]])
    myord=c(myord, j)
}
datc <- dat[,myord]
datc[datc==-1]=0
colnames(datc) <- mytimes

# %%
# normalize by the total number of cuts per timepoint
datn <- datc
for (i in seq(1,ncol(datc))){
    tot=sum(datc[,i])
    datn[,i]=datc[,i]/tot
}
datn <- datn *1000000

# %%
datn[1,]
# Out:
#   _1min     _5min _10min   _15min    _30min    _on
# 1 0.6042417 0     0.213826 0.2915178 0.7588898 0.6783448

# %%
mymax=600
hdat <- make_hist_data(datc, mymax)
mydens = hdat[[1]]
mycnts = hdat[[2]]
dfm <- melt(data.frame(mycnts), id="mids")
pc <- ggplot(dfm, aes(colour=variable, y=value, x=mids)) + geom_line() + 
    xlim(0, mymax)  +  ylab("Number of cutsites") + xlab("Number of reads") + scale_y_log10()

# %%
mymax=50
hdat <- make_hist_data(datn, mymax)
mydens = hdat[[1]]
mycnts = hdat[[2]]
dfm <- melt(data.frame(mycnts), id="mids")
pn <- ggplot(dfm, aes(colour=variable, y=value, x=mids)) + geom_line() + 
    xlim(0, mymax)  +  ylab("Number of cutsites") + xlab("Fraction of reads") + scale_y_log10()

# %%
options(repr.plot.width=8, repr.plot.height=3)
grid.arrange(pc, pn, ncol=2)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 180 rows containing missing values (geom_path).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 180 rows containing missing values (geom_path).”
# plot without title

# %%
dat <- read.table("BICRO62_all_umiQuant.txt", header=T)
mymax=1

myord=c()
for (i in seq(1,length(mytimes))){
    j=grep(mytimes[i], labels(dat)[[2]])
    myord=c(myord, j)
}
datc <- dat[,myord]
datc[datc==-1]=0
colnames(datc) <- mytimes

mydens <- make_hist_data(datc, mymax)
dfm <- melt(data.frame(mydens), id="mids")
p2 <- ggplot(dfm, aes(colour=variable, y=value, x=mids)) + geom_line() + 
    xlim(0, mymax)  +  ylab("Number of cutsites") + xlab("Normalized peak height") + scale_y_log10()

# %%
options(repr.plot.width=8, repr.plot.height=3)
grid.arrange(p, p2, ncol=2)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 180 rows containing missing values (geom_path).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 180 rows containing missing values (geom_path).”
# plot without title

# %% [markdown]
# ## Difference between time points

# %%
dat <- datc
datd <- c()
for (i in seq(2,(length(mytimes)))){
    t2=grep(mytimes[i], labels(dat)[[2]])
    t1=grep(mytimes[i-1], labels(dat)[[2]])
    mydif <- dat[,t2] - dat[,t1]
    if (length(datd)==0){
        datd <- mydif   
    }
    else {
        datd <- cbind(datd, mydif) 
    }
}
colnames(datd) <- mytimes[2:length(mytimes)]
mymax=200
densd <- make_hist_data(datd, mymax)

# %%
dfm <- melt(data.frame(densd), id="mids")
p <- ggplot(dfm, aes(colour=variable, y=value, x=mids)) + geom_line() + 
    xlim(-1*mymax, mymax) + xlab("Difference in reads\nfrom t=1_min") + ylab("Number of cutsites") + scale_y_log10()

options(repr.plot.width=4, repr.plot.height=3)
grid.arrange(p)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# plot without title

# %% [markdown]
# ## Second derivatives across time points

# %%
datdd <- c()
dat <- datc
for (i in seq(3,(length(mytimes)))){
    t3 <- grep(mytimes[i], labels(dat)[[2]])
    t2 <- grep(mytimes[i-1], labels(dat)[[2]])
    t1 <- grep(mytimes[i-2], labels(dat)[[2]])
    d1 <- dat[,t2] - dat[,t1]
    d2 <- dat[,t3] - dat[,t2]
    dd <- d2 - d1
    if (length(datdd)==0){
        datdd <- dd 
    }
    else {
        datdd <- cbind(datdd, dd) 
    }
}
colnames(datdd) <- mytimes[3:length(mytimes)]

# %%
mymax=100
densdd <- make_hist_data(datdd, mymax)

# %%
dfm <- melt(data.frame(densdd), id="mids")
p <- ggplot(dfm, aes(colour=variable, y=value, x=mids)) + geom_line() + 
    xlim(-1*mymax,mymax) + xlab("Second derivative\nfrom t=1_min") + ylab("Number of cutsites") + scale_y_log10()

options(repr.plot.width=4, repr.plot.height=3)
grid.arrange(p)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# plot without title

# %% [markdown]
# try clustering samples or making a heat map of them using just cutsites with  average >= 2 reads per sample and with differences > 5 reads between t=0.

# %%
mdif <- apply(mydif, 1, mean)
stdif <- apply(mydif, 1, sd)

# %%
# Do this because there is an outlier cutsite that has thousands of cuts 
ifilt <- mdif < 20
df3 <- data.frame(mean=mdif[ifilt], std<-std[ifilt])

# %%
p <- ggplot(df3, aes(x=mean, y=std)) + geom_point(size=.1, alpha=0.1) + 
    xlab("Mean") + ylab("Std")
p3 <- ggExtra::ggMarginal(p, type="density", size=5, margin="both")
# Out:
# Warning message:
# “Removed 618 rows containing missing values (geom_point).”Warning message:
# “Removed 618 rows containing non-finite values (stat_density).”

# %%
options(repr.plot.width=4, repr.plot.height=3)
grid.arrange(p3)
# Out:
# plot without title

# %% [markdown]
# # Looking at centrality measure

# %% [markdown]
# Compare old centrality estimate (B58) to the new one (B52) for the Hap1 cells.
#
# ```
# cd GPSeq_data2/centrality
# sed 1d B52.estimated.1Mb.tsv | awk '{print $1"_"$2"\t"$0}' | sort > tmp52
# sed 1d ../../GPSeq_data/centrality_estimates/B58.size1Mb.step100kb.tsv | awk '{print $1"_"$2"\t"$0}' | sort > tmp58
# join tmp52 tmp58 | tr ' ' '\t' | cut -f2-6,10,11 > tmp
# ```
#
# Note that I also looked at this for the B62 (IMR90) data, and the scores are basically identical, presumably because it's the same set of experiments that have just been rescored.

# %%
dat <- read.table("GPSeq_data2/centrality/tmp")
df <- data.frame(B52=dat[,4], B58=dat[,6])

cor.test(dat[,4], dat[,6])
p <- ggplot(df, aes(x=B52, y=B58)) + geom_point(size=.1, alpha=0.1)
options(repr.plot.width=3, repr.plot.width=3)
p
# Out:
# 	Pearson's product-moment correlation
#
# data:  dat[, 4] and dat[, 6]
# t = 307.27, df = 26348, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.8815401 0.8868096
# sample estimates:
#      cor
# 0.884203
# plot without title

# %% [markdown]
# Look at correlation between the centrality measures for the different cell types

# %%
dat52 <- read.table("GPSeq_data2/centrality/B52.estimated.1Mb.tsv", header=T)
dat62 <- read.table("GPSeq_data2/centrality/B62+83.estimated.1Mb.tsv", header=T)

# %%
cor.test(dat52$prob_g, dat62$prob_g)
# Out:
# 	Pearson's product-moment correlation
#
# data:  dat52$prob_g and dat62$prob_g
# t = 110.34, df = 26348, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.5538551 0.5703726
# sample estimates:
#       cor
# 0.5621699

# %%
df <- data.frame(B52=dat52$prob_g, B62=dat62$prob_g)
p <- my_scatter_plot(x=dat52$prob_g, y=dat62$prob_g, quantile=TRUE, 
                                 myxlab="B52 (Hap1) centrality", myylab="B62 (IMR90) centrality")
options(repr.plot.width=3, repr.plot.width=3)
p
# Out:
# plot without title

# %% [markdown]
# Look at relationship between the 'estimate', 'ranked', and 'rescaled' values

# %%
dates <- read.table("GPSeq_data2/centrality/B52.estimated.1Mb.tsv", header=T)
datre <- read.table("GPSeq_data2/centrality/B52.rescaled.1Mb.tsv", header=T)

# %%
dates[1,]
datre[1,]
# Out:
#   chrom start  end     prob_g  var_2p
# 1 chr1  100000 1100000 13.4715 8.63084
#   chrom start  end     prob_g   var_2p
# 1 chr1  100000 1100000 2.237021 1.913058

# %%
cor.test(dates$prob_g, datre$prob_g)
# Out:
# 	Pearson's product-moment correlation
#
# data:  dates$prob_g and datre$prob_g
# t = 1238.1, df = 26348, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.9913089 0.9917170
# sample estimates:
#       cor
# 0.9915154

# %%
df <- data.frame(estimate=dates$prob_g, rescaled=datre$prob_g)
p <- ggplot(df, aes(x=estimate, y=rescaled)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="Centrality for B52, Hap1", x="estimate", y="rescaled")
options(repr.plot.width=3, repr.plot.width=3)
p
# Out:
# plot without title

# %% [markdown]
# # HiC eigenvector data

# %%
datk <- read.table("hic_data/KBM7/KBM7_combined.50kb_bins.txt", header=F)
dati <- read.table("hic_data/IMR90/IMR90_combined.50kb_bins.txt", header=F)
colnames(datk) <- c("chr", "start", "end", "id", "eigen")
colnames(dati) <- c("chr", "start", "end", "id", "eigen")

# %%
datk[1,]
cor.test(datk[,5], dati[,5])
# Out:
#   chr  start end   id eigen
# 1 chr1 0     49999 1  0.03144353
# 	Pearson's product-moment correlation
#
# data:  datk[, 5] and dati[, 5]
# t = 2.1555, df = 57239, p-value = 0.03113
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.0008171428 0.0172000472
# sample estimates:
#       cor
# 0.0090092

# %%
df <- data.frame(KBM7=datk[,5], IMR90=dati[,5])
p <- ggplot(df, aes(x=KBM7, y=IMR90)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (50kb)")
options(repr.plot.width=3, repr.plot.width=3)
p
# Out:
# Warning message:
# “Removed 4662 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Flip them both so they match GC content

# %%
gcdat <- read.table("chromatin_data/hg19_50kb_gc5.txt", header=T)
gcdat[1,]
# Out:
#   chr  start end   id hg19.gc5Base
# 1 chr1 0     49999 1  38.7404

# %%
chrs <- rle(as.character(gcdat$chr))

for (c in chrs$values){
    myc <- cor(datk[datk$chr==c,5], gcdat[gcdat$chr==c,5], use="complete.obs")
    if (!is.na(myc) && myc < 0){
        datk[datk$chr==c,5] = -1 * datk[datk$chr==c,5]
    }
    myc <- cor(dati[dati$chr==c,5], gcdat[gcdat$chr==c,5], use="complete.obs")
    if (!is.na(myc) && myc < 0){
        dati[datk$chr==c,5] = -1 * dati[dati$chr==c,5]
    }
}

# %%
cor.test(dati[,5], datk[,5])
# Out:
# 	Pearson's product-moment correlation
#
# data:  dati[, 5] and datk[, 5]
# t = 176.4, df = 57239, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.5881024 0.5987169
# sample estimates:
#       cor
# 0.5934355

# %%
df <- data.frame(KBM7=datk[,5], IMR90=dati[,5])
p <- ggplot(df, aes(x=KBM7, y=IMR90)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (50kb)")
options(repr.plot.width=3, repr.plot.width=3)
p
# Out:
# Warning message:
# “Removed 4662 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## KBM7 data

# %%
datk <- read.table("hic_data/KBM7/KBM7_combined.1Mb_bins_join.txt")
datgc <- read.table("hic_data/GC5.1Mb_bins_join.txt")
dat52 <- read.table("hic_data/B52estimated.1Mb_bins_join.txt")

# %%
colnames(datk) <- c("chr", "start", "end", "eigen")
colnames(datgc) <- c("chr", "start", "end", "id", "gc")
colnames(dat52) <- c("chr", "start", "end", "prob_g", "var_g")
datk[1,]
datgc[1,]
dat52[1,]
# Out:
#   chr  start   end     eigen
# 1 chr1 1000000 2000000 0.08661009
#   chr  start   end     id gc
# 1 chr1 1000000 2000000 10 56.8915
#   chr  start   end     prob_g  var_g
# 1 chr1 1000000 2000000 14.4002 8.41648

# %%
df <- data.frame(hic=datk[,4], gc=datgc[,5], prob_g=dat52[,4])
cor.test(df$hic, df$gc)
p <- ggplot(df, aes(x=hic, y=gc)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (50kb)")
options(repr.plot.width=3, repr.plot.width=3)
p
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$hic and df$gc
# t = 2.7363, df = 2628, p-value = 0.006255
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.01511059 0.09133651
# sample estimates:
#       cor
# 0.0533012
# plot without title

# %% [markdown]
# flip eigenvectors to match GC content

# %%
chrs <- rle(as.character(datk$chr))
datnewk <- datk
mycors=c()
for (c in chrs$values){
    myc <- cor(datk[datk$chr==c,4], datgc[datgc$chr==c,5], use="complete.obs")
    mycors <- c(mycors, myc)
    if (!is.na(myc) && myc < 0){
        datnewk[datk$chr==c,4] = -1 * datk[datk$chr==c,4]
    }
}

# %%
df[1,]
datnewk[1,]
# Out:
#   hic        gc      prob_g
# 1 0.08661009 56.8915 14.4002
#   chr  start   end     eigen
# 1 chr1 1000000 2000000 0.08661009

# %%
mycors
# Out:
#  [1]  0.8063265 -0.5261628  0.8214686  0.8308518 -0.8100385 -0.8078803
#  [7] -0.7283016 -0.7273546  0.6225456 -0.7390556 -0.7782336  0.6574283
# [13]  0.7814822  0.7511743  0.2525135  0.7452373  0.6568764 -0.6782090
# [19] -0.7333755 -0.7609406  0.6689721 -0.4907993  0.7099688

# %%
df <- data.frame(hic=datk[,4], gc=datgc[,5], prob_g=dat52[,4], var_g=dat52$var_g, hicflip=datnewk[,4])
cor.test(df$hic, df$prob_g)
cor.test(df$hicflip, df$prob_g)

p1 <- ggplot(df, aes(x=hic, y=prob_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (50kb)")
p2 <- ggplot(df, aes(x=hicflip, y=prob_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors, corrected")
options(repr.plot.height=3, repr.plot.width=6)
grid.arrange(p1, p2, ncol=2)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$hic and df$prob_g
# t = 3.7016, df = 2628, p-value = 0.0002186
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.03389183 0.10993868
# sample estimates:
#        cor
# 0.07201992
# 	Pearson's product-moment correlation
#
# data:  df$hicflip and df$prob_g
# t = 33.603, df = 2628, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.5209073 0.5743996
# sample estimates:
#       cor
# 0.5482139
# plot without title

# %%
cor.test(df$hic, df$var_g)
cor.test(df$hicflip, df$var_g)
p1 <- ggplot(df, aes(x=hic, y=var_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (50kb)")
p2 <- ggplot(df, aes(x=hicflip, y=var_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors, corrected")
options(repr.plot.height=3, repr.plot.width=6)
grid.arrange(p1, p2, ncol=2)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$hic and df$var_g
# t = 3.559, df = 2628, p-value = 0.0003789
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.03111887 0.10719550
# sample estimates:
#        cor
# 0.06925788
# 	Pearson's product-moment correlation
#
# data:  df$hicflip and df$var_g
# t = 20.566, df = 2628, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.3389425 0.4048008
# sample estimates:
#       cor
# 0.3723403
# plot without title

# %%
Correlation of prob_g and eigen vectors per chromosome

# %%
chrs <- rle(as.character(datk$chr))
mycors=c()
for (c in chrs$values){
    myc <- cor(datk[datk$chr==c,4], dat52[dat52$chr==c,5], use="complete.obs")
    mycors <- c(mycors, myc)
}
dfcor <- data.frame(cbind(chrs$values, chrs$lengths, mycors))

# %%
dfcor
# Out:
#    V1    V2  mycors
# 1  chr1  215 0.581269436842131
# 2  chr10 120 -0.276111209398382
# 3  chr11 118 0.57820588797721
# 4  chr12 123 0.589200186593383
# 5  chr13 89  -0.514533316783846
# 6  chr14 83  -0.491547027095516
# 7  chr15 69  0.108551045484408
# 8  chr16 71  -0.336826092658674
# 9  chr17 73  0.416430679890428
# 10 chr18 69  -0.518795644290108
# 11 chr19 51  -0.273900181291077
# 12 chr2  227 0.372676347399808
# 13 chr20 53  0.410186643362953
# 14 chr21 33  0.632523756777426
# 15 chr22 27  0.610808633567425
# 16 chr3  187 0.509879247324176
# 17 chr4  182 0.455142241379974
# 18 chr5  164 -0.358828659508078
# 19 chr6  157 -0.504966729496513
# 20 chr7  145 -0.507273522176557
# 21 chr8  130 0.473020220596692
# 22 chr9  105 -0.365324707049088
# 23 chrX  139 0.414153018388188

# %%
xi <- datk$chr=="chr22"
sum(xi)
cor.test(df$hicflip[xi], df$prob_g[xi])
# Out:
# [1] 27
#  [1] 0.08661009 0.07097558 0.06734219 0.02718054 0.02836997 0.09223768
#  [7] 0.04940809 0.09181982 0.08761754 0.08675107
# 	Pearson's product-moment correlation
#
# data:  df$hicflip[xi] and df$prob_g[xi]
# t = 4.3227, df = 25, p-value = 0.0002155
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.3646212 0.8281935
# sample estimates:
#       cor
# 0.6540142

# %% [markdown]
# ## IMR90 data

# %%
datmr <- read.table("hic_data/IMR90/IMR90_combined.1Mb_bins_join.GC.txt", header=T)

# %%
datmr[1,]
# Out:
#   chr  start   end     GC      prob_g   var_2p   eigen
# 1 chr1 1000000 2000000 56.8915 11.54033 7.698281 0.1080616

# %%
df <- data.frame(datmr)
cor.test(df$prob_g, df$eigen)
p1 <- ggplot(df, aes(x=eigen, y=prob_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(x="IMR90 Eigenvectors", y="prob_g", title="HiC eigenvectors (1Mb)")
options(repr.plot.height=3, repr.plot.width=3)
grid.arrange(p1)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$prob_g and df$eigen
# t = -4.0296, df = 2628, p-value = 5.746e-05
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.11623659 -0.04026256
# sample estimates:
#         cor
# -0.07836335
# plot without title

# %% [markdown]
# correct and flip the eigenvectors for GC

# %%
chrs <- rle(as.character(datmr$chr))
datnewmr <- datmr
mycors=c()
mycors2=c()
x=0
for (c in chrs$values){
    myc <- cor(datmr$GC[datmr$chr==c], datmr$eigen[datmr$chr==c], use="complete.obs")
    mycors <- c(mycors, myc)
    if (!is.na(myc) && myc <0){
        x=x+1
        datnewmr$eigen[datmr$chr==c] = -1 * datmr$eigen[datmr$chr==c]
    }
    myc <- cor(datmr$GC[datmr$chr==c], datnewmr$eigen[datmr$chr==c], use="complete.obs")
    mycors2 <- c(mycors2, myc)
}

# %%
x
# Out:
# [1] 13

# %%
mycors
# Out:
#  [1]  0.5896563  0.3860589 -0.6434288 -0.5944969  0.7016538 -0.6119552
#  [7]  0.4442245 -0.7794203  0.4914836 -0.5243970 -0.6769179  0.5757410
# [13] -0.7538897 -0.7576701 -0.4585757 -0.6188303 -0.6173507  0.5339756
# [19]  0.5182238  0.3719682  0.4800739 -0.7511077 -0.1598666

# %%
mycors2
# Out:
#  [1] 0.5896563 0.3860589 0.6434288 0.5944969 0.7016538 0.6119552 0.4442245
#  [8] 0.7794203 0.4914836 0.5243970 0.6769179 0.5757410 0.7538897 0.7576701
# [15] 0.4585757 0.6188303 0.6173507 0.5339756 0.5182238 0.3719682 0.4800739
# [22] 0.7511077 0.1598666

# %%
datmr[1,]
# Out:
#   chr  start   end     GC      prob_g   var_2p   eigen
# 1 chr1 1000000 2000000 56.8915 11.54033 7.698281 0.1080616

# %%
df <- data.frame(hic=datmr$eigen, gc=datmr$GC, prob_g=datmr$prob_g, var_g=datmr$var_2p, hicflip=datnewmr$eigen)

# %%
cor.test(df$hic, df$gc)
cor.test(df$hicflip, df$gc)

p1 <- ggplot(df, aes(x=hic, y=gc)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (1Mb)")
p2 <- ggplot(df, aes(x=hicflip, y=gc)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors, corrected")
options(repr.plot.height=3, repr.plot.width=6)
grid.arrange(p1, p2, ncol=2)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$hic and df$gc
# t = -3.8562, df = 2628, p-value = 0.0001179
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.11290762 -0.03689433
# sample estimates:
#         cor
# -0.07500994
# 	Pearson's product-moment correlation
#
# data:  df$hicflip and df$gc
# t = 29.208, df = 2628, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.4656259 0.5233561
# sample estimates:
#       cor
# 0.4950372
# plot without title

# %%
cor.test(df$hic, df$prob_g)
cor.test(df$hicflip, df$prob_g)

p1 <- ggplot(df, aes(x=hic, y=prob_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors (1Mb)")
p2 <- ggplot(df, aes(x=hicflip, y=prob_g)) + geom_point(size=.1, alpha=0.1) + 
    labs(title="HiC eigenvectors, corrected")
options(repr.plot.height=3, repr.plot.width=6)
grid.arrange(p1, p2, ncol=2)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$hic and df$prob_g
# t = -4.0296, df = 2628, p-value = 5.746e-05
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.11623659 -0.04026256
# sample estimates:
#         cor
# -0.07836335
# 	Pearson's product-moment correlation
#
# data:  df$hicflip and df$prob_g
# t = -5.5441, df = 2628, p-value = 3.249e-08
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.14514551 -0.06958519
# sample estimates:
#        cor
# -0.1075206
# plot without title
